# %%
from ColoniesDataset import ColoniesDataset
dataset = ColoniesDataset('/Users/lapofrati/PlayGround/cell_manager/data')

# %%
len(dataset)
# Out:
# 149

# %%
dataset[0]
# Out:
# ('LIeVhUPi_I9zf6nC1L2',
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x114C37908>,
#  [[0.5283333333333333, 0.12666666666666668, 0.025027378419648263],
#   [0.6033333333333334, 0.16666666666666666, 0.025027378419648263],
#   [0.6666666666666666, 0.2, 0.025027378419648263],
#   [0.7533333333333333, 0.2733333333333333, 0.025027378419648263],
#   [0.8216666666666667, 0.3466666666666667, 0.025027378419648263],
#   [0.8533333333333334, 0.42, 0.025027378419648263],
#   [0.8466666666666667, 0.53, 0.025027378419648263],
#   [0.8966666666666666, 0.51, 0.025027378419648263],
#   [0.8933333333333333, 0.59, 0.025027378419648263],
#   [0.75, 0.59, 0.025027378419648263],
#   [0.6733333333333333, 0.475, 0.025027378419648263],
#   [0.5633333333333334, 0.7133333333333334, 0.025027378419648263],
#   [0.5766666666666667, 0.5983333333333334, 0.025027378419648263],
#   [0.52, 0.6316666666666667, 0.025027378419648263],
#   [0.53, 0.5533333333333333, 0.025027378419648263],
# ...

# %%
import utilities as utils
utils.show_sample(3,3, dataset, utils.bound_colonies)
#utils.show_sample(3,3,dataset, utils.dot_colonies)
